# %%
import cv2
import time

cascade_src = r'cars1.xml'

video_src = r'video3.MP4'

#line a

ax1=70

ay=90

ax2=230



#line b

bx1=15

by=125

bx2=225

def Speed_Cal(time):

 

    try:        

        Speed = (9.144/1000)/(time/3600)                

        return Speed                 

    except ZeroDivisionError :        

        print ("can not devide by zero")                 

        

#car num

i = 1

start_time = time.time()

#video ....

cap = cv2.VideoCapture(video_src)

car_cascade = cv2.CascadeClassifier(cascade_src)   
while True:

    ret, img = cap.read()       

    if (type(img) == type(None)):       

        break               

    #bluring to have exacter detection        

    blurred = cv2.blur(img,ksize=(15,15))        

    gray = cv2.cvtColor(blurred, cv2.COLOR_BGR2GRAY)        

    cars = car_cascade.detectMultiScale(gray, 1.1, 2)        


    #line a #i know road has got        

    cv2.line(img,(ax1,ay),(ax2,ay),(255,0,0),2)        

    #line b         

    cv2.line(img,(bx1,by),(bx2,by),(255,0,0),2)        

    for (x,y,w,h) in cars:        

        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),2)               

        cv2.circle(img,(int((x+x+w)/2),int((y+y+h)/2)),5,(0,255,0),-1)               

        while int(ay) == int((y + y+h)/2):              

            cv2.line(img,(ax1,ay),(ax2,ay),(0,255,0),2)                     

            start_time = time.time()                     

            break                      

            

        while int(ay) <= int((y+y+h)/2):              

            if int(by) <= int((y+y+h)/2) & int( by + 10 ) >= int(( y + y+h)/2):                     

                cv2.line(img,(bx1,by),(bx2,by),(0,255,0),2)                              

                Speed = Speed_Cal(time.time() - start_time)                              

                print("Car Number "+str(i)+" Speed: "+str(Speed)+ " KM/H ")                               

                i = i + 1                                

                break                                

            else :                       

                cv2.putText(img, "Calcuting", (100,200), cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,0),3)                            

                break                       

    cv2.imshow('video', img) 

    if cv2.waitKey(33) == 27:

        break

cap.release()#close cam

cv2.destroyAllWindows() #close window
# Out:
# Car Number 1 Speed: 8.180537399051785 KM/H
# Car Number 2 Speed: 63.7844697678587 KM/H
# Car Number 3 Speed: 70.86923216761033 KM/H
# Car Number 4 Speed: 18.570610370237265 KM/H
# Car Number 5 Speed: 5.507640873534715 KM/H
# Car Number 6 Speed: 4.6688436872731955 KM/H
# Car Number 7 Speed: 4.25076037977051 KM/H
# Car Number 8 Speed: 4.225536752790796 KM/H
# Car Number 9 Speed: 64.84867918502921 KM/H
# Car Number 10 Speed: 64.86366806284838 KM/H
# Car Number 11 Speed: 11.953697877143803 KM/H
# Car Number 12 Speed: 7.154468673931829 KM/H
# Car Number 13 Speed: 7.083493877752047 KM/H
# Car Number 14 Speed: 3.665986114782325 KM/H
# Car Number 15 Speed: 2.961126287416986 KM/H
# Car Number 16 Speed: 2.948821762446576 KM/H
# Car Number 17 Speed: 2.9242164951661502 KM/H
# Car Number 18 Speed: 2.912424922061341 KM/H
# Car Number 19 Speed: 2.8203612804195357 KM/H
# Car Number 20 Speed: 59.45814358413424 KM/H
# Car Number 21 Speed: 54.7445166355481 KM/H
# Car Number 22 Speed: 11.400264434511042 KM/H
# Car Number 23 Speed: 11.212093390920293 KM/H

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\atefi\anaconda3\envs\yolo\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\atefi\anaconda3\envs\yolo\lib\site-packages (from opencv-python) (1.24.4)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atefi\anaconda3\envs\yolo\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atefi\anaconda3\envs\yolo\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\atefi\anaconda3\envs\yolo\lib\site-packages)
